# %% [markdown]
# ## Sentiment Analysis of Stock Market News using FinBERT

# %% [markdown]
# * Importing required libraries

# %%
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from urllib.request import urlopen, Request

# %% [markdown]
# *   Webscraping the data from a finance news website which segregates its stocks alphabetically and uses a tick (keyword) in its URL to navigate to a particular stock.
# *   The get_ticks function extracts all the ticks in one go from tickettape/stocks. Using Beautifulsoup and urllib, we extract both the tick and name of stock and store them in a pandas dataframe in alphabetical order.

# %%
def get_ticks(url):
    req = Request(url=url,headers={"User-Agent": "Chrome"}) 
    response = urlopen(req)    
    html = BeautifulSoup(response,"html.parser")
    ticks_table = html.find(class_ = 'page')
    
    ticks = list()
    stocks = list()
    for name_box in ticks_table.find_all('a', href = True):
        stocks.append(name_box.text.strip())
        ticks.append(name_box['href'].split('-')[-1].strip())
    d = {'stock':stocks, 'tick':ticks}
    df = pd.DataFrame(data = d)
    return df

# %% [markdown]
# * Calling the defined function and first few rows of output

# %%
url = "https://www.tickertape.in/stocks"
tick_df = get_ticks(url)
tick_df.head()
# Out:
#                                        stock  tick
# 0                              ABB India Ltd   ABB
# 1                      Adani Enterprises Ltd  ADEL
# 2                     Adani Green Energy Ltd  ADNA
# 3  Adani Ports and Special Economic Zone Ltd  APSE
# 4                            Adani Power Ltd  ADAN

# %% [markdown]
# * Using similar method to extract news information related to each stock

# %%
def get_data(url):
    req = Request(url=url,headers={"User-Agent": "Chrome"}) 
    response = urlopen(req).read()    
    html = BeautifulSoup(response,"html.parser")
    news_table = html.find(class_ = 'latest-news-holder')
    
    news = list()
    
    for name_box in news_table.find_all('p', class_='shave-root'):
        news.append(name_box.text.strip())
    
    return news

# %% [markdown]
# * Running a for loop where we replace the stock-tick part with the elements in the tick column of our DataFrame we can extract the news of each stock and store it in a list called news.

# %%
news = list()
for i, tick in enumerate(tick_df['tick']):
    url = "https://www.tickertape.in/stocks/" + tick + "/news?checklist=basic&ref=stock-overview_overview-sections&type=news"
    headlines = get_data(url)
    news.append(headlines)

# %% [markdown]
# * Installing transformers package for sentiment analysis

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.25.1-py3-none-any.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 34.8 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.8/dist-packages (from transformers) (6.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.8/dist-packages (from transformers) (4.64.1)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 50.4 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers) (3.8.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 52.2 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers) (2.10)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.11.1 tokenizers-0.13.2 transformers-4.25.1

# %% [markdown]
# * Initiating pretrained FinBERT model for our analysis

# %%
from transformers import BertTokenizer, BertForSequenceClassification

finbert = BertForSequenceClassification.from_pretrained('yiyanghkust/finbert-tone',num_labels=3)
tokenizer = BertTokenizer.from_pretrained('yiyanghkust/finbert-tone')
# Out:
# Downloading:   0%|          | 0.00/533 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/439M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]

# %% [markdown]
# * Mapping the numeric format of sentiment in FinBERT model to a more Human friendly model using python dictionary called labels.

# %%
labels = {0:'neutral', 1:'positive',2:'negative'}

# %% [markdown]
# * Preprocessing the text: we use tokenizer and then pass the output from the tokenizer to the finbert object for sentiment analysis.
# * We do this for every stock in our list. The sentiment for each headline is stored in a list so that we can later group them to create an aggregate sentiment of each stock.
# * We store the output from the function in a list of lists called tot_val. Some lists appear empty as the website does not contain the news. For those stocks, we just return neutral as the sentiment.

# %%
def detect(news):
    tot_val = list()
    for n in news:
        if len(n) == 0:
            tot_val.append(['neutral'])
        else:
            inputs = tokenizer(n, return_tensors="pt", padding=True)
            outputs = finbert(**inputs)[0]
            val = list()
            for idx, sent in enumerate(n):
                val.append(labels[np.argmax(outputs.detach().numpy()[idx])])
                print(sent, '----', val[idx])
            print('#######################################################')    
            tot_val.append(val)
    return tot_val

tot_val = detect(news)
# Out:
# Accumulate ABB India; target of Rs 3291: Prabhudas Lilladher ---- positive
# #######################################################
# Reliance hit most as top 5 out of 10 firms lose ₹1.67 lakh crore in m-cap ---- negative
# Stocks in news: Paytm, HUL, Adani Enterprises, Lupin and more ---- neutral
# HUL, Adani Enterprises, One 97 Communications in spotlight ---- neutral
# #######################################################
# F&O Strategy: Buy Adani Ports 880-put ---- neutral
# Equities muted as oil slide offsets concerns over Fed’s rate stance ---- negative
# Stocks that will see action on December 7, 2022 ---- neutral
# #######################################################
# Adani Transmission incorporates wholly-owned subsidiary Adani Cooling Sol ---- neutral
# Reliance Is Biggest And Adani Transmission Fastest Wealth Creator Of 2017-2022 ---- positive
# Reliance continues to remain big wealth creator: Motilal Oswal study ---- neutral
# #######################################################
# Geoclean to help ACC, Ambuja Cements cut carbon emission ---- neutral
# #######################################################
# Paras Healthcare appoints Santy Sajan as the new Group Chief Operating Officer ---- neutral
# #######################################################
# Sensex falls 51 pts, Nifty ends flat; Asian Paints, Infosys, Titan top losers ---- negative
# Taking Stock | Sensex falls 215 points, Nifty below 18,600 amid volatility after RBI rate hike ---- neutral
# #######################################################
# Axis Bank mops up ₹12,000 crore via NCDs at 7.88% coupon rate ---- neutral
# Lenders betting big on supply chain finance ---- neutral
# Sanjiv Bhasin’s stock picks for next week: Axis Bank, GAIL.... ---- neutral
# #######################################################
# Sensex snaps two-day losing streak; IndusInd Bank, Bajaj Finance, Infosys top gainers ---- neutral
# Bajaj Finance, Kotak Bank and BSE are Vaishali Parekh’s 3 technical picks ---- neutral
# Sensex snaps two-day losing streak, jumps 403 points ---- neutral
# #######################################################
# Sensex snaps two-day losing streak, jumps 403 points ---- neutral
# Sensex surges 403 pts; Nifty tops 18,600; PSU Bank index leaps 4%, IT 1% ---- positive
# Taking Stock | Sensex falls 215 points, Nifty below 18,600 amid volatility after RBI rate hike ---- neutral
# #######################################################
# Bank of Baroda hikes MCLR by up to 30 bps; home loan, other loan EMIs to go up ---- neutral
# Golden Jubilee Hotel lenders seek debt buyers ---- neutral
# Bank of Baroda hikes MCLR up to 30 basis effective December 12 ---- neutral
# #######################################################
# Trade setup for Wednesday: Top 15 things to know before the opening bell ---- neutral
# Here’s why Mehul Kothari is bullish on BPCL, Thomas Cook ---- neutral
# BPCL, HPCL, IOCL - Drop In Crude Prices Augurs Well: Prabhudas Lilladher ---- neutral
# #######################################################
# Stocks in news: Uniparts India, Bharti Airtel, Vodafone Idea, Marico and more ---- neutral
# Stocks that will see action on December 12, 2022 ---- neutral
# Stocks to Watch: Uniparts, Glenmark, SBI, Airtel, Marico, Hero MotoCorp ---- neutral
# #######################################################
# Nifty Bank support at 42,800 level; IndusInd, HDFC Bank, SBI, PNB & Canara Bank may do well ---- positive
# Home loan rate: Punjab National Bank, Canara Bank hike their home loan interest rates; details here ---- neutral
# PNB, Canara Bank hike home loan interest rates; check details here ---- neutral
# #######################################################
# Cholamandalam Investment & Finance Company Ltd spurts 0.81%, gains for fifth straight session ---- positive
# #######################################################
# Higher output could boost Coal India’s spot sales, says Pramod Agrawal ---- positive
# Power demand growth to boost Coal India’s spot auctions: Chairman Pramod Agrawal ---- positive
# India’s Nov thermal coal imports at 10 month-low as local output soars ---- neutral
# #######################################################
# Phoenix Mills, TCI Express, DLF, GSPL and Greenpanel Ind: Here’s what analysts said on these 5 stocks ---- neutral
# As RBI hikes repo rate. Here’s what industry experts say ---- neutral
# Real estate shares tank up to 3% as RBI hikes repo rate; here’s what industry experts say ---- neutral
# #######################################################
# Foreign broking firm raises target of these 5 stocks; do you own any? ---- neutral
# Online grocery prices rise as brands slash discounts ---- positive
# 2 top technical stock picks from Osho Krishnan ---- positive
# #######################################################
# Rs 3,000 or Rs 3,500, where are Eicher Motors shares headed? Analysts decode ---- neutral
# Stocks in news: Infosys, Tech Mahindra, Inox Wind, Metro Brands and more ---- neutral
# Equities muted as oil slide offsets concerns over Fed’s rate stance ---- negative
# #######################################################
# Peaking gas and power units to run under special scheme next summer ---- neutral
# Sanjiv Bhasin’s stock picks for next week: Axis Bank, GAIL.... ---- neutral
# GAIL wins best ‘Energy Transition – Midstream Company’ award ---- positive
# #######################################################
# Tube Investments, JK Lakshmi Cement, GCPL & L&T among Axis Securities’ top 4 technical picks ---- neutral
# #######################################################
# Sensex snaps two-day losing streak; IndusInd Bank, Bajaj Finance, Infosys top gainers ---- neutral
# Sensex snaps two-day losing streak, jumps 403 points ---- neutral
# Sensex surges 403 pts; Nifty tops 18,600; PSU Bank index leaps 4%, IT 1% ---- positive
# #######################################################
# HDFC-HDFC Bank merger: BSE, NSE give in-principle approval ---- neutral
# SBI vs HDFC Bank vs ICICI Bank: Check latest FD rates here ---- neutral
# HDFC Bank merger to shake up debt market ---- neutral
# #######################################################
# Sula Vineyards collects Rs 288 cr from anchor investors ahead of IPO ---- neutral
# #######################################################
# Stocks to Watch: Uniparts, Glenmark, SBI, Airtel, Marico, Hero MotoCorp ---- neutral
# Hero MotoCorp expands role of Niranjan Gupta - CFO ---- neutral
# Hero MotoCorp announces resignation of Malo Le Masson; CFO takes charge ---- neutral
# #######################################################
# Trade setup for Monday: Top 15 things to know before the opening bell ---- neutral
# History suggests real estate, metals & IT stocks gain big in Decembers. Here’re top stock picks ---- positive
# #######################################################
# India’s space exploration sector will potentially hit $13 billion by 2025, making it ripe for startups ---- positive
# #######################################################
# Inflation data pushes indices up after 2 days; Sensex up 403 points ---- positive
# What analysts say on Bharat Dalmia, Paytm, SBI Card, HUL and Dr Lal Pathlabs ---- neutral
# Markets settle lower; Sensex falls for third day ---- negative
# #######################################################
# Govt to check foreign fund appetite in Hindustan Zinc before stake dilution ---- neutral
# Government to assess appetite of foreign funds in Hindustan Zinc before stake dilution ---- neutral
# #######################################################
# Amazon India Smartphone Upgrade Days sale: Deals from Xiaomi, Realme, Oppo you should check out ---- neutral
# Siemens: Here’s what experts said on the stock post analyst meet ---- neutral
# Sensex, Nifty end flat ahead of inflation data; HDFC duo, RIL lend support ---- positive
# #######################################################
# Stocks in news: Tata Motors, ICICI Bank, Macrotech Developers, KEC International and more ---- neutral
# SBI vs HDFC Bank vs ICICI Bank: Check latest FD rates here ---- neutral
# ICICI Bank raises Rs 5,000 cr via bonds ---- neutral
# #######################################################
# Will look to expand banca partnerships with PSBs’, says ICICI Lombard chief Bhargav Dasgupta ---- neutral
# Trade setup for today: Top 15 things to know before the opening bell ---- neutral
# #######################################################
# Sula Vineyards collects Rs 288 cr from anchor investors ahead of IPO ---- neutral
# ICICI Prudential Life Insurance Company Ltd down for fifth straight session ---- neutral
# India remains a very attractive investment destination from a 5-10 years perspective: Jitendra Arora, ICICI Prudential Life ---- positive
# #######################################################
# Ahluwalia Contracts Shares Surge As IDBI Capital Initiates Coverage With “Buy” Rating ---- positive
# Concor EoIs in January; IDBI bidders may get more time ---- neutral
# IDBI Bank, Concor divestment likely to take longer: Officials ---- neutral
# #######################################################
# Why ITC shares are a good bet despite 55% rally in 2022 ---- positive
# SABC promotes integrated pest management to tackle black thrips in chilli in AP, Telangana ---- neutral
# Ishan Kishan’s coach recollects 200 balls of power-hitting, shadow batting ---- neutral
# #######################################################
# Delighted to see so many women in IOA’s Executive Council: Nita Ambani ---- neutral
# IOC to look to allow Russian, Belarus athletes’ international participation ---- neutral
# IOC may allow Russian, Belarus athletes to participate internationally ---- neutral
# #######################################################
# Indian Overseas Bank Increases Interest Rates On Fixed Deposits Under Rs 2 Crore ---- neutral
# Indian Overseas Bank spurts 1.55%, up for fifth straight session ---- positive
# Indian Overseas Bank fixed deposit interest rate hiked from today; Check revised FD rates, return calculator for senior citizens ---- neutral
# #######################################################
# Hold Indian Railway Catering and Tourism Corporation; target of Rs 679: Prabhudas Lilladher ---- neutral
# #######################################################
# Sensex snaps two-day losing streak; IndusInd Bank, Bajaj Finance, Infosys top gainers ---- neutral
# Share Market News: Sensex, Nifty climb as inflation cools; Tata Motors, IndusInd Bank, TechM top gainers ---- positive
# Sensex snaps two-day losing streak, jumps 403 points ---- neutral
# #######################################################
# Accessible, quality data essential to meet development goals: G20 Working Group ---- neutral
# Sensex snaps two-day losing streak; IndusInd Bank, Bajaj Finance, Infosys top gainers ---- neutral
# Sensex snaps two-day losing streak, jumps 403 points ---- neutral
# #######################################################
# Delhi airport chaos: IndiGo asks passengers to report 3.5 hours prior to departure ---- neutral
# Delhi Airport Terminal 3 Congestion Advisory: ‘Reach 3.5 hours early...’ to avoid missing flight, says IndiGo ---- neutral
# ‘Reach at least 3.5 hrs prior to departure’: IndiGo issues advisory amid congestion at Delhi airport ---- neutral
# #######################################################
# Govt plans to invite EoIs for divestment of RINL by Jan-end ---- neutral
# Top five steel companies, few others selected under the PLI scheme ---- neutral
# Andhra Pradesh government gives green signal to JSW’s steel plant, Adani’s 1,600 MW hydroelectric energy storage project ---- neutral
# #######################################################
# Stocks to Watch: Paytm, HUL, ICICI Bank, HDFC Bank, Jindal Steel, Pharma ---- neutral
# Jindal Steel and Power acquires Monnet Power through bankruptcy court ---- neutral
# Jindal Steel and Power acquires Monnet Power through insolvency route ---- neutral
# #######################################################
# Bajaj Finance, Kotak Bank and BSE are Vaishali Parekh’s 3 technical picks ---- neutral
# Kotak Bank sells 6.5 per cent stake in Shriram City Union Finance ---- neutral
# Dhanlaxmi Bank hikes interest rates on Fixed Deposits, Kotak Mahindra Bank revises FD rates: Know who’s eligible ---- neutral
# #######################################################
# India’s space exploration sector will potentially hit $13 billion by 2025, making it ripe for startups ---- positive
# Tube Investments, JK Lakshmi Cement, GCPL & L&T among Axis Securities’ top 4 technical picks ---- neutral
# Siemens: Here’s what experts said on the stock post analyst meet ---- neutral
# #######################################################
# Maruti Suzuki, Hyundai emerge top PV sellers; overall sales hit 2.76 lakh in Nov: SIAM ---- neutral
# Sensex surges 403 pts; Nifty tops 18,600; PSU Bank index leaps 4%, IT 1% ---- positive
# Bolero, Scorpio among most sold Mahindra cars in Nov this year; XUV700 sells 5,701 units ---- neutral
# #######################################################
# Stocks in news: Uniparts India, Bharti Airtel, Vodafone Idea, Marico and more ---- neutral
# Marico Ltd soars 0.81%, gains for fifth straight session ---- positive
# Stocks to Watch: Uniparts, Glenmark, SBI, Airtel, Marico, Hero MotoCorp ---- neutral
# #######################################################
# Inflation data pushes indices up after 2 days; Sensex up 403 points ---- positive
# Maruti Suzuki, Hyundai emerge top PV sellers; overall sales hit 2.76 lakh in Nov: SIAM ---- neutral
# Maruti Suzuki India seeks correct accounting of GHG emission benefits of ethanol ---- neutral
# #######################################################
# NTPC’s 240 MW Devikot solar project begins commercial operation ---- neutral
# NTPC commissions entire capacities of 150 MW & 90 MW Devikot Solar PV Projects ---- neutral
# Stocks in news: Uniparts India, Bharti Airtel, Vodafone Idea, Marico and more ---- neutral
# #######################################################
# Inflation data pushes indices up after 2 days; Sensex up 403 points ---- positive
# Nestle to launch new Ukraine facility in rare war-time investment ---- neutral
# Markets settle lower; Sensex falls for third day ---- negative
# #######################################################
# Stocks to Watch Today: Tata Motors, Paytm, ICICI Bank, ONGC, Dalmia Bharat, and Others ---- neutral
# Stocks to watch: Dalmia Bharat, ICICI Bank, Paytm, ONGC, KEC International ---- neutral
# ONGC to invest Rs 2,150 cr on drilling 53 exploratory wells in Andhra ---- neutral
# #######################################################
# No change likely in Nifty’s March reshuffling ---- neutral
# #######################################################
# Stocks to Watch: Paytm, Dalmia, ICICI Bank, Tata Motors, HCL Tech ---- neutral
# Nifty Bank support at 42,800 level; IndusInd, HDFC Bank, SBI, PNB & Canara Bank may do well ---- positive
# PNB shares at Rs 72? What made JPMorgan upgrade PSU bank to overweight? ---- positive
# #######################################################
# Reliance Industries Ltd is India’s most-visible company, says report ---- neutral
# Reliance Industries tops charts on Wizikey Newsmaker Ranking ---- neutral
# Reliance hit most as top 5 out of 10 firms lose ₹1.67 lakh crore in m-cap ---- negative
# #######################################################
# Equities muted as oil slide offsets concerns over Fed’s rate stance ---- negative
# Taking Stock | Sensex falls 215 points, Nifty below 18,600 amid volatility after RBI rate hike ---- neutral
# #######################################################
# Share price of SRF rises as Nifty weakens ---- positive
# #######################################################
# Dalmia-Jaypee deal: Battle for third spot in cement market intensifies ---- negative
# #######################################################
# Accumulate Siemens; target of Rs 3290: Prabhudas Lilladher ---- positive
# Siemens: Here’s what experts said on the stock post analyst meet ---- neutral
# Siemens, others call for only zero-emission freight trucks to be sold in EU by 2035 - Times of India ---- neutral
# #######################################################
# NCLT allows SBI petition seeking insolvency proceedings against Bil Energy ---- neutral
# What analysts say on Bharat Dalmia, Paytm, SBI Card, HUL and Dr Lal Pathlabs ---- neutral
# SBI vs HDFC Bank vs ICICI Bank: Check latest FD rates here ---- neutral
# #######################################################
# Stocks in news: Paytm, HUL, Adani Enterprises, Lupin and more ---- neutral
# Sun Pharma shares rise after five sessions of losses, here’s why ---- negative
# IT selloff drags Sensex 400 pts lower, Nifty sheds 120 pts: HCL Tech tanks ---- negative
# #######################################################
# TCS partners with Gujarat government for learning initiative ---- neutral
# How Bengaluru airport, TCS employees helped a Danish man find his late grandfather’s lost watch ---- neutral
# TCS, Gujarat Govt to jointly impart digital skills in schools ---- neutral
# #######################################################
# Online grocery prices rise as brands slash discounts ---- positive
# #######################################################
# Auto sales rise in November on higher supplies ---- positive
# Tata Motors to raise commercial vehicles prices from January 2023 ---- neutral
# Stocks in news: Tata Motors, ICICI Bank, Macrotech Developers, KEC International and more ---- neutral
# #######################################################
# Auto sales rise in November on higher supplies ---- positive
# Tata Motors to raise commercial vehicles prices from January 2023 ---- neutral
# Stocks in news: Tata Motors, ICICI Bank, Macrotech Developers, KEC International and more ---- neutral
# #######################################################
# Tata Power gets shareholders’ nod to appoint Rajiv Mehrishi as independent director ---- neutral
# Tata Power gets shareholder nod to appoint Mehrishi as independent director ---- neutral
# Tata Power shares trading in consolidation zone; can they hit Rs 400 mark? ---- neutral
# #######################################################
# Inflation data pushes indices up after 2 days; Sensex up 403 points ---- positive
# Govt plans to invite EoIs for divestment of RINL by Jan-end ---- neutral
# Top five steel companies, few others selected under the PLI scheme ---- neutral
# #######################################################
# Sensex snaps two-day losing streak, jumps 403 points ---- neutral
# Tech Mahindra rewards employees with shares worth over Rs 6 lakh as stock options ---- neutral
# Sensex tumbles 389 points to close at 62,182, Nifty in red at 18,497 ---- neutral
# #######################################################
# Inflation data pushes indices up after 2 days; Sensex up 403 points ---- positive
# Apple Car to debut in 2026, expected to be priced under 81 Lakh ---- neutral
# Byju’s lenders seek immediate part-repayment of $1.2 billion loan ---- neutral
# #######################################################
# Tube Investments, JK Lakshmi Cement, GCPL & L&T among Axis Securities’ top 4 technical picks ---- neutral
# #######################################################
# Sensex surges 403 pts; Nifty tops 18,600; PSU Bank index leaps 4%, IT 1% ---- positive
# Markets settle lower; Sensex falls for third day ---- negative
# #######################################################
# Union Bank of India hikes home loan, other loan interest rates: Check latest rates ---- neutral
# Vakrangee Ltd leads losers in ‘A’ group ---- negative
# #######################################################
# Broker’s call: Varun Beverages (Buy) ---- neutral
# #######################################################
# Vedanta Shares Rise After Inking Semiconductor Pact ---- positive
# Vedanta inks pacts with 30 Japanese firms to develop Indian semiconductor manufacturing ecosystem ---- neutral
# Vedanta inks pacts with 30 Japanese firms for semiconductor manufacturing ---- neutral
# #######################################################
# Wipro shares settle higher, halt 6-day losing run. Here’s what analysts say ---- neutral
# Why Wipro shares have fallen more than TCS, Infosys since 2021 ---- negative
# Infosys vs TCS vs Wipro: Which stock is Nomura’s top IT sector pick? ---- neutral
# #######################################################
# YES Bank shares surge 27% in 4-day rally. Rs 25 level looks likely in 3-5 months, suggest technical charts ---- positive
# Yes Bank to allot shares, warrants to Carlyle Group, Advent International ---- neutral
# YES Bank re-enters top-100 most valued firms list; stock up 30% in 3 days ---- positive
# #######################################################
# I ordered Delhi’s Chole Bhature in Mumbai using Zomato, here’s how it went! ---- neutral
# Mumbai: Post Malone gets injured while performing at the Zomato Feeding India Concert ---- neutral
# Zerodha’s Nikhil Kamath wonders about retail investors’ appetite for ‘next round of startups that IPO’; here’s why ---- neutral
# #######################################################

# %% [markdown]
# * Next, we create an aggregate of the sentiments by combining the sentiments of each headline of every stock. For this purpose, we simply add +1 to the agg variable if the headline was positive and -1 if the headline was negative. Based on the final value of the agg variable we assign positive, negative, or neutral to the stock.

# %%
def get_sent(val):
    agg = 0
    for i in val:
        if i == 'positive':
            agg = agg + 1
        elif i == 'negative':
            agg = agg - 1

    if agg > 0:
        return('positive')
    elif agg < 0:
        return('negative')
    else:
        return('neutral')

# %% [markdown]
# * We pass our list of sentiments through the get_sent() and obtain the aggregate sentiments. We store these sentiments in a list which we then assign into a column sentiment of our original tick_df DataFrame.
# * Looking at the first few rows of the output

# %%
sent = list()
for i in tot_val:
    sent.append(get_sent(i))
    
tick_df['sentiment'] = sent 
tick_df.head(20)
# Out:
#                                         stock  tick sentiment
# 0                               ABB India Ltd   ABB  positive
# 1                       Adani Enterprises Ltd  ADEL  negative
# 2                      Adani Green Energy Ltd  ADNA   neutral
# 3   Adani Ports and Special Economic Zone Ltd  APSE  negative
# 4                             Adani Power Ltd  ADAN   neutral
# 5                         Adani Total Gas Ltd  ADAG   neutral
# 6                      Adani Transmission Ltd  ADAI  positive
# 7                            Adani Wilmar Ltd   AWL   neutral
# 8                          Ambuja Cements Ltd  ABUJ   neutral
# 9             Apollo Hospitals Enterprise Ltd  APLH   neutral
# 10                           Asian Paints Ltd  ASPN  negative
# 11                      Avenue Supermarts Ltd  AVEU   neutral
# 12                              Axis Bank Ltd  AXBK   neutral
# 13                             Bajaj Auto Ltd  BAJA   neutral
# 14                          Bajaj Finance Ltd  BJFN   neutral
# 15                          Bajaj Finserv Ltd  BJFS  positive
# 16          Bajaj Holdings and Investment Ltd  BJAT   neutral
# 17                         Bank of Baroda Ltd   BOB   neutral
# 18                    Berger Paints India Ltd  BRGR   neutral
# 19                     Bharat Electronics Ltd  BAJE   neutral

# %% [markdown]
# * Looking at the last few rows of the output

# %%
tick_df.tail(20)
# Out:
#                                 stock   tick sentiment
# 80  Sun Pharmaceutical Industries Ltd    SUN  negative
# 81      Tata Consultancy Services Ltd    TCS   neutral
# 82         Tata Consumer Products Ltd   TACN  positive
# 83                    Tata Motors Ltd  TAMdv  positive
# 84                    Tata Motors Ltd   TAMO  positive
# 85             Tata Power Company Ltd   TTPW   neutral
# 86                     Tata Steel Ltd   TISC  positive
# 87                  Tech Mahindra Ltd   TEML   neutral
# 88                  Titan Company Ltd   TITN  positive
# 89        Torrent Pharmaceuticals Ltd   TORP   neutral
# 90      Tube Investments of India Ltd   TBEI   neutral
# 91                            UPL Ltd   UPLL   neutral
# 92               UltraTech Cement Ltd   ULTC   neutral
# 93            Union Bank of India Ltd   UNBK  negative
# 94                 United Spirits Ltd   UNSP   neutral
# 95                Varun Beverages Ltd   VARB   neutral
# 96                        Vedanta Ltd   VDAN  positive
# 97                          Wipro Ltd   WIPR  negative
# 98                       Yes Bank Ltd   YESB  positive
# 99                         Zomato Ltd    ZOM   neutral
